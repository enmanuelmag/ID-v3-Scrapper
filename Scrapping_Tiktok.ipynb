# %%
import os
import pickle
import importlib

import utils

utils = importlib.reload(utils)

from utils import SearcherDriver, build_url_search, clean_url, clean_text, parse_text_number

# %% [markdown]
# ### Constants

# %%
TIKTOK_COOKIE = 'tiktok_cookie.pkl'

URL_BASE = 'https://www.tiktok.com/search'
FILE = './data/tiktok_violencia_guayaquil.csv'

RUNS = [
  [
    'ladrones',
    'guayaquil',
    'guayas',
  ],
  [
    'delincuencia',
    'guayaquil',
    'guayas',
  ],
  [
    'grupos armados',
    'tiroteo',
    'guayaquil',
    'guayas',
  ],
  [
    'balacera',
    'guayaquil',
    'guayas',
  ],
  [
    'sicarios',
    'sicariato',
    'guayaquil',
    'guayas',
  ],
  [
    'mafias',
    'grupo delicuencia organizada',
    'guayaquil',
    'guayas',
  ],
  [
    'violencia',
    'guayaquil',
    'guayas',
  ],
  [
    'robo',
    'secuestro',
    'guayaquil',
    'guayas',
  ],
  [
    'extorsion',
    'guayaquil',
    'guayas',
  ],
  [
    'inseguridad',
    'guayaquil',
    'guayas',
  ]
]

# %% [markdown]
# ### Scraping functions

# %%
def save_cookie(ds: SearcherDriver, path: str):
  with open(path, 'wb') as f:
    pickle.dump(ds.driver.get_cookies(), f)


def load_cookie(driver, path):
  if not os.path.exists(path):
    print('[WARNING] Cookie file not found')
    return
  
  with open(path, 'rb') as f:
    cookies = pickle.load(f)
    for cookie in cookies:
      driver.add_cookie(cookie)
  
  return driver


def login(sd: SearcherDriver):
  # button by id xpath
  btn_login_xpath = '//button[@id="header-login-button"]'
  sd.get_element_by('xpath', btn_login_xpath).click()


def check_capcha(sd: SearcherDriver):
  #print('[INFO] Checking capcha')
  capcha_xpath = '//div[@id="captcha-verify-container-main-page"]'
  capcha = sd.get_element_by('xpath', capcha_xpath, timeout=2, from_capcha=True)

  if capcha is not None:
    print('[WARNING] Capcha detected')

    if input('Please solve the capcha and press "y" to continue: ').lower() == 'y':
      return True

  return False


def go_next_video(sd: SearcherDriver):
  print('[INFO] Going to next video')
  btn_next_xpath = '//button[@aria-label="Go to next video"]'
  btn = sd.get_element_by('xpath', btn_next_xpath)

  try:
    if btn is not None and btn.is_displayed():
      btn.click()
      return True
  except Exception as e:
    print('[WARNING] Clicking next video:', e)

  return False


def get_comments(sd: SearcherDriver, total_comments: int, comments_per_scroll = 25):
  print('[INFO] Scroll comments')
  container_xpath = '//div[contains(@class, "DivCommentListContainer")]'
  container = sd.get_element_by('xpath', container_xpath)

  if container is None:
    return ''

  iter_scrolls = min(total_comments // comments_per_scroll, 12)

  print(f'[INFO] Scrolling {iter_scrolls} times')
  for _ in range(int(iter_scrolls)):
    sd.driver.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight', container)

  print('[INFO] Getting comments')
  comments_xpath = '//div[contains(@class, "DivCommentContentContainer")]/div[1]/p[contains(@class, "PCommentText")]'
  comments = sd.get_elements_by('xpath', comments_xpath)

  return '|'.join(list(map(lambda c: clean_text(c.text), comments)))


def get_video_info(sd: SearcherDriver):
  info = [clean_url(sd.driver.current_url)]

  btn_more_xpath = '//button[contains(@class, "ButtonExpand") and contains(text(), "more")]'
  btn_more = sd.get_element_by('xpath', btn_more_xpath)
  
  try:
    if btn_more is not None and btn_more.is_displayed():
      print('[INFO] Clicking more button')
      btn_more.click()
  except Exception as e:
    print('[WARMING] Clicking more button:', e)

  desc_xpath = '//h1[@data-e2e="browse-video-desc"]'
  desc = sd.get_element_by('xpath', desc_xpath)
  info.append(desc and clean_text(desc.text) or '')

  username_xpath = '//span[@data-e2e="browse-username"]'
  username = sd.get_element_by('xpath', username_xpath)
  info.append(username and clean_text(username.text) or '')

  date_xpath = '//span[@data-e2e="browser-nickname"]/span[3]'
  date_video = sd.get_element_by('xpath', date_xpath)
  info.append(date_video and clean_text(date_video.text) or '')

  like_count_xpath = '//strong[@data-e2e="browse-like-count"]'
  like_count = sd.get_element_by('xpath', like_count_xpath)
  info.append(like_count and clean_text(like_count.text) or '')

  comment_count_xpath = '//strong[@data-e2e="browse-comment-count"]'
  comment_count = sd.get_element_by('xpath', comment_count_xpath)
  info.append(comment_count and clean_text(comment_count.text) or '')

  share_count_xpath = '//strong[@data-e2e="undefined-count"]'
  share_count = sd.get_element_by('xpath', share_count_xpath)
  info.append(share_count and clean_text(share_count.text) or '')

  comments = get_comments(sd, parse_text_number(info[-2]))
  info.append(comments)

  return '\t'.join(info)

# %% [markdown]
# ### Login and Run session

# %%
def browser_save_cookie(sd: SearcherDriver, search: str):
  sd.get(search)
  login(sd)

  if input('Enter "y" to save cookie: ').lower() == 'y':
    save_cookie(sd, TIKTOK_COOKIE)
    print('Cookie saved')
  else:
    print('Cookie not saved')

def scraper_with_cookie(sd: SearcherDriver, search: str):
  sd.get(search)

  load_cookie(sd.driver, TIKTOK_COOKIE)

  sd.driver.refresh()

  first_video_xpath = '//div[@mode="search-video-list"]/div[1]'
  sd.get_element_by('xpath', first_video_xpath).click()

  counter = len(sd.url_scraped)

  if not sd.is_url_scraped():
    sd.append_data(get_video_info(sd))
    counter += 1
    print(f'[INFO] Videos added: {counter}')
    sd.random_sleep(1, 5)

  while True:
    try:
      result = go_next_video(sd)

      if not result:
        print('[INFO] No more videos')
        break

      is_scraped = sd.is_url_scraped()

      if not is_scraped:
        sd.append_data(get_video_info(sd))
        counter += 1
        print(f'[INFO] Videos added: {counter}')
      
      sd.random_sleep(1, 3 if is_scraped else 7)
    except Exception as e:
      print('[ERROR] Error in loop:', e)
      break

# %% [markdown]
# # Steps to scrap
# If this is the first time you are running this notebook you will need to install selenium:
# - `!pip install selenium`
# Also need to download the chromedriver from [here](https://googlechromelabs.github.io/chrome-for-testing/) and put it in the same folder as this notebook and set the path to the chromedriver.
#
# If you are using linux or mac you can use `homebrew` to install chromedriver and dont need to set explicitly the path to the chromedriver:
# - `brew install chromedriver`
#
# # Login and Scrap
# First we need get the cookies os a active session. The cell code below detect if the cookies are already saved in the file `tiktok_cookies.pkl` and if not it will open a browser and ask you to login in the site. After login you must enter "y" in the input prompted on terminal/vscode and the cookies will be saved in the file `tiktok_cookies.pkl`. Finally, `restart the kernel` run all the cells code again, now the cookies will be loaded from the file `tiktok_cookies.pkl`.
#
# You can customize the search changing the `KEYWORDS` variable.

# %%
searcher = SearcherDriver(file=FILE, check_captcha_fn=check_capcha)


if not os.path.exists(TIKTOK_COOKIE):
  print('[WARNING] Cookie file not found')
  url_search = build_url_search(URL_BASE, [])
  searcher.run(lambda sd: browser_save_cookie(sd, url_search))
else:
  for run_keys in RUNS:
    url_search = build_url_search(URL_BASE, run_keys)
    searcher.run(lambda sd: scraper_with_cookie(sd, url_search))
# Out:
# [WARNING] No executable path provided. Searching for chromedriver in PATH
# [DRIVER] Scraped URLs: ['link', 'https://www.tiktok.com/@teleamazonas.noticias/video/7428993372175535366', 'https://www.tiktok.com/@ecuadorcomunicacionec/video/7366828063893490949', 'https://www.tiktok.com/@periodicodeunaec/video/7303179925329071365', 'https://www.tiktok.com/@queradiomasvacan1/video/7239036507682540806', 'https://www.tiktok.com/@queradiomasvacan2/video/7277623430801919238', 'https://www.tiktok.com/@periodicodeunaec/video/7220879299400830214', 'https://www.tiktok.com/@ecuadorcomunicacionec/video/7450677984467438853', 'https://www.tiktok.com/@dannytrellesc/video/7241324303256505605', 'https://www.tiktok.com/@andresvillalval/video/7445338536473103621', 'https://www.tiktok.com/@extraec/video/7247179929044012294', 'https://www.tiktok.com/@ecuavisaec/video/7413795223978904837']
# [DRIVER] Running <lambda>
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: True - Current URL: https://www.tiktok.com/@teleamazonas.noticias/video/7428993372175535366?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] URL already scraped: https://www.tiktok.com/@teleamazonas.noticias/video/7428993372175535366?q=ladrones%20guayaquil%20guayas%20
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: True - Current URL: https://www.tiktok.com/@queradiomasvacan2/video/7277623430801919238?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] URL already scraped: https://www.tiktok.com/@queradiomasvacan2/video/7277623430801919238?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: True - Current URL: https://www.tiktok.com/@periodicodeunaec/video/7303179925329071365?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] URL already scraped: https://www.tiktok.com/@periodicodeunaec/video/7303179925329071365?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@periodicodeunaec/video/7443832795467648311?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 13
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: True - Current URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7366828063893490949?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] URL already scraped: https://www.tiktok.com/@ecuadorcomunicacionec/video/7366828063893490949?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: True - Current URL: https://www.tiktok.com/@queradiomasvacan1/video/7239036507682540806?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] URL already scraped: https://www.tiktok.com/@queradiomasvacan1/video/7239036507682540806?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: True - Current URL: https://www.tiktok.com/@periodicodeunaec/video/7220879299400830214?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] URL already scraped: https://www.tiktok.com/@periodicodeunaec/video/7220879299400830214?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: True - Current URL: https://www.tiktok.com/@dannytrellesc/video/7241324303256505605?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] URL already scraped: https://www.tiktok.com/@dannytrellesc/video/7241324303256505605?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: True - Current URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7450677984467438853?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] URL already scraped: https://www.tiktok.com/@ecuadorcomunicacionec/video/7450677984467438853?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: True - Current URL: https://www.tiktok.com/@extraec/video/7247179929044012294?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] URL already scraped: https://www.tiktok.com/@extraec/video/7247179929044012294?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: True - Current URL: https://www.tiktok.com/@andresvillalval/video/7445338536473103621?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] URL already scraped: https://www.tiktok.com/@andresvillalval/video/7445338536473103621?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: True - Current URL: https://www.tiktok.com/@ecuavisaec/video/7413795223978904837?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] URL already scraped: https://www.tiktok.com/@ecuavisaec/video/7413795223978904837?q=ladrones%20guayaquil%20guayas%20
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@periodicodeunaec/video/7338102906446417157?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 14
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@jomijomi._/video/7317714287034682630?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 11 times
# [INFO] Getting comments
# [INFO] Videos added: 15
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7364225793653820677?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 1 times
# [INFO] Getting comments
# [INFO] Videos added: 16
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@periodicodeunaec/video/7450865670264376581?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 17
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7356811391258463493?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 18
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@aquilesalcalde/video/7327347197236858118?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 3 times
# [INFO] Getting comments
# [INFO] Videos added: 19
# [DRIVER] Sleeping for 5 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@periodicodeunaec/video/7312977277950659845?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 20
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@elsemanario.ec/video/7445355580992081158?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [WARMING] Elements not found: //div[contains(@class, "DivCommentContentContainer")]/div[1]/p[contains(@class, "PCommentText")]
# [INFO] Videos added: 21
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@extraec/video/7330327117021940997?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 3 times
# [INFO] Getting comments
# [WARNING] Capcha detected
# [INFO] Videos added: 22
# [DRIVER] Sleeping for 5 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@henrybustamant/video/7381462775031450885?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 23
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@rtsecuador_/video/7365197925670079749?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 24
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@digitalinformativa/video/7285853566349151493?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 4 times
# [INFO] Getting comments
# [INFO] Videos added: 25
# [DRIVER] Sleeping for 5 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@franp7615/video/7444945563130268983?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 26
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@guayaquilalrojovivo.com/video/7397151850799090950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 6 times
# [INFO] Getting comments
# [INFO] Videos added: 27
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7229057538958855430?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 28
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@teleamazonas.noticias/video/7426034203801750789?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 29
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@periodicodeunaec/video/7308069502904831238?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 30
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@extraec/video/7312135082863594758?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 31
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@periodicodeunaec/video/7417893697200639237?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 32
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@vanerobles30/video/7192579897959730437?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 1 times
# [INFO] Getting comments
# [INFO] Videos added: 33
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7399811560283081989?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 34
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@periodicodeunaec/video/7420961584215837957?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 1 times
# [INFO] Getting comments
# [INFO] Videos added: 35
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7447329858125958405?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 36
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@periodicodeunaec/video/7302878771558862085?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 37
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@sucrenoticias/video/7264669151304731910?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 1 times
# [INFO] Getting comments
# [INFO] Videos added: 38
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@liamcito_6.21/video/7419032705813302533?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 39
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@periodicodeunaec/video/7208921302105640197?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 40
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@alojo.ec/video/7422342485508197637?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 41
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@eluniversocom/video/7374122022550473990?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 42
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@reporterinternacional/video/7171908583624297733?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 43
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7401164409265032454?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 7 times
# [INFO] Getting comments
# [INFO] Videos added: 44
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@ultimahoracol_/video/7159194609695034630?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 45
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@tctelevisionec/video/7271250140156005637?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [WARNING] Capcha detected
# [INFO] Videos added: 46
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@reporterinternacional/video/7191697678449904902?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 47
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@henrybustamant/video/7345110706997546245?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 10 times
# [INFO] Getting comments
# [INFO] Videos added: 48
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@incomprendible64/video/7322272087551331589?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 49
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@periodicodeunaec/video/7399457826763984133?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 50
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@guayacaenuk/video/7206394397116796166?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 51
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@codigorojolatino/video/7455681243535904006?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 52
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@y.mimita/video/7444668450250804536?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 1 times
# [INFO] Getting comments
# [INFO] Videos added: 53
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7426862012912635141?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 54
# [DRIVER] Sleeping for 5 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@alertaguayaquil593/video/7250521752902569222?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 1 times
# [INFO] Getting comments
# [INFO] Videos added: 55
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@hechosec/video/7201568418431012102?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 1 times
# [INFO] Getting comments
# [INFO] Videos added: 56
# [DRIVER] Sleeping for 5 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@xq.podcast/video/7423818887453510918?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [WARMING] Elements not found: //div[contains(@class, "DivCommentContentContainer")]/div[1]/p[contains(@class, "PCommentText")]
# [INFO] Videos added: 57
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@guayacaenuk/video/7208289717543046406?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 58
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@todonoticias/video/7262825733599399174?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 59
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@maker_ao/video/7112968556547017989?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 60
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@periodicodeunaec/video/7187615129444306181?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 61
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@liamcito_6.21/video/7236575845882531077?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 6 times
# [INFO] Getting comments
# [INFO] Videos added: 62
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@beautygirl_ecu/video/7286592080330149125?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 10 times
# [INFO] Getting comments
# [INFO] Videos added: 63
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@altavoz.ec/video/7457670627764309253?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 64
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@periodicodeunaec/video/7219497975020604677?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 65
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@luisalfredozm/video/7317102600439057670?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 66
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@extraec/video/7389404398830587142?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 6 times
# [INFO] Getting comments
# [INFO] Videos added: 67
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@alertaecuador7/video/7153600858742181125?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 68
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@queradiomasvacan1/video/7204965850623921413?q=ladrones%20guayaquil%20guayas%20
# [WARNING] Capcha detected
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 69
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@liam.3.01/video/7203803372829412613?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 70
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@peladoangel5/video/7235514649179966725?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 71
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@bryanhidalgopezo/video/7436358956076846391?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 72
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@itzan_stephano/video/6919654974456679686?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 3 times
# [INFO] Getting comments
# [INFO] Videos added: 73
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@hablaserio95/video/7256269620284312837?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 11 times
# [INFO] Getting comments
# [INFO] Videos added: 74
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@extraec/video/7326923184375139589?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 6 times
# [INFO] Getting comments
# [INFO] Videos added: 75
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@abg.guayaquil/video/7224045292960615685?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 1 times
# [INFO] Getting comments
# [INFO] Videos added: 76
# [DRIVER] Sleeping for 5 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@ecuadorplay/video/7299932708183002373?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 77
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@reporterinternacional/video/7286641902689062149?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 78
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@edercheme/video/7210580050448633094?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 6 times
# [INFO] Getting comments
# [INFO] Videos added: 79
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@la.voz.de.paquito/video/7390461529184800006?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 80
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@extraec/video/7317711556991651078?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 81
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@ecuavisaec/video/7392672776504511749?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 8 times
# [INFO] Getting comments
# [INFO] Videos added: 82
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@wqradio/video/7444928847943945527?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 83
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@guayaquilcaliente/video/7202021819803651334?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 84
# [DRIVER] Sleeping for 5 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@noticiasgranda66/video/7450325247082908933?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 3 times
# [INFO] Getting comments
# [INFO] Videos added: 85
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lamachitv/video/7330465163180543238?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 86
# [DRIVER] Sleeping for 5 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@mullin.44/video/7275707319525100805?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 87
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@epp9x19/video/7387073939094211845?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 5 times
# [INFO] Getting comments
# [INFO] Videos added: 88
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@rtsecuador_/video/7238972605145844998?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 6 times
# [INFO] Getting comments
# [INFO] Videos added: 89
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@novicompu/video/7234313622434876677?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 90
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@periodicodeunaec/video/7435869747536825655?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 1 times
# [INFO] Getting comments
# [INFO] Videos added: 91
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@acontecer.noticioso/video/7455827705968200965?q=ladrones%20guayaquil%20guayas%20
# [WARNING] Capcha detected
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 92
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@dial593radio/video/7456856365022104838?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 93
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lamagia_tv/video/7304903251881659653?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 1 times
# [INFO] Getting comments
# [INFO] Videos added: 94
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@maricartasec/video/7457661915909590277?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 12 times
# [INFO] Getting comments
# [INFO] Videos added: 95
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@periodicodeunaec/video/7190848991381277957?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 96
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@dimenews/video/7322262070555184390?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 1 times
# [INFO] Getting comments
# [INFO] Videos added: 97
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@nathalymarilin/video/7458441192162774277?q=ladrones%20guayaquil%20guayas%20
# [INFO] Clicking more button
# [INFO] Scroll comments
# [INFO] Scrolling 0 times
# [INFO] Getting comments
# [INFO] Videos added: 98
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 99
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 100
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 101
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 102
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 103
# [DRIVER] Sleeping for 5 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 104
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 105
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 106
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 107
# [DRIVER] Sleeping for 5 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 108
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 109
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 110
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 111
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 112
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 113
# [DRIVER] Sleeping for 5 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 114
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 115
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 116
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 117
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 118
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 119
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 120
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 121
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 122
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 123
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 124
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 125
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 126
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 127
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 128
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 129
# [DRIVER] Sleeping for 5 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 130
# [DRIVER] Sleeping for 6 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 131
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 132
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 133
# [DRIVER] Sleeping for 7 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 134
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 135
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
# [INFO] Scroll comments
# [INFO] Scrolling 2 times
# [INFO] Getting comments
# [INFO] Videos added: 136
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Checking if URL is already scraped
# [DRIVER] Scraped: False - Current URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7235860470953970950?q=ladrones%20guayaquil%20guayas%20
