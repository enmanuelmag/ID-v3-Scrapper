# %%
import os
import pickle
import importlib

import utils

utils = importlib.reload(utils)

from utils import SearcherDriver, build_url_search, clean_url, clean_text, parse_text_number

# %% [markdown]
# ### Constants

# %%
TIKTOK_COOKIE = 'tiktok_cookie.pkl'

URL_BASE = 'https://www.tiktok.com/search'
FILE = './data/tiktok_violencia_<location>.csv'

RUNS = [
  [
    'delincuencia',
    'grupos armados',
    'robo',
    'extorsion',
    'secuestro',
    'guayas',
    'ecuador',
  ],
  [
    'delincuencia',
    'grupos armados',
    'robo',
    'extorsion',
    'secuestro',
    'tiroteo',
    'manabí',
    'ecuador',
  ],
  [
    'delincuencia',
    'grupos armados',
    'robo',
    'extorsion',
    'secuestro',
    'los ríos',
    'ecuador',
  ],
  [
    'delincuencia',
    'grupos armados',
    'robo',
    'extorsion',
    'secuestro',
    'esmeraldas',
    'ecuador',
  ],
  [
    'delincuencia',
    'grupos armados',
    'robo',
    'extorsion',
    'secuestro',
    'machala',
    'ecuador',
  ],
  [
    'delincuencia',
    'grupos armados',
    'robo',
    'extorsion',
    'secuestro',
    'santo domingo',
    'ecuador',
  ]
]

# %% [markdown]
# ### Scraping functions

# %%
def save_cookie(ds: SearcherDriver, path: str):
  with open(path, 'wb') as f:
    pickle.dump(ds.driver.get_cookies(), f)


def load_cookie(driver, path):
  if not os.path.exists(path):
    print('[WARNING] Cookie file not found')
    return
  
  with open(path, 'rb') as f:
    cookies = pickle.load(f)
    for cookie in cookies:
      driver.add_cookie(cookie)
  
  return driver


def login(sd: SearcherDriver):
  # button by id xpath
  btn_login_xpath = '//button[@id="header-login-button"]'
  sd.get_element_by('xpath', btn_login_xpath).click()


def check_capcha(sd: SearcherDriver):
  capcha_xpath = '//div[@id="captcha-verify-container-main-page"]'
  capcha = sd.get_element_by('xpath', capcha_xpath, timeout=2, from_capcha=True)

  if capcha is not None:
    print('[WARNING] Capcha detected')

    if input('Please solve the capcha and press "y" to continue: ').lower() == 'y':
      return True

  return False


def go_next_video(sd: SearcherDriver):
  print('[INFO] Going to next video')
  btn_next_xpath = '//button[@aria-label="Go to next video"]'
  btn = sd.get_element_by('xpath', btn_next_xpath)

  try:
    if btn is not None and btn.is_displayed():
      btn.click()
      return True
  except Exception as e:
    print('[WARNING] Button next video not found:', e)

  return False


def get_comments(sd: SearcherDriver, total_comments: int, comments_per_scroll = 25):
  container_xpath = '//div[contains(@class, "DivCommentListContainer")]'
  container = sd.get_element_by('xpath', container_xpath)

  if container is None:
    print('[WARNING] Comments container not found')
    return ''

  iter_scrolls = min(total_comments // comments_per_scroll, 12)

  print(f'[INFO] Scrolling {iter_scrolls} times')
  for _ in range(int(iter_scrolls)):
    sd.driver.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight', container)

  comments_xpath = '//div[contains(@class, "DivCommentContentContainer")]/div[1]/p[contains(@class, "PCommentText")]'
  comments = sd.get_elements_by('xpath', comments_xpath)

  return '|'.join(list(map(lambda c: clean_text(c.text), comments)))


def get_video_info(sd: SearcherDriver):
  info = [clean_url(sd.driver.current_url)]

  btn_more_xpath = '//button[contains(@class, "ButtonExpand") and contains(text(), "more")]'
  btn_more = sd.get_element_by('xpath', btn_more_xpath)
  
  try:
    if btn_more is not None and btn_more.is_displayed():
      btn_more.click()
  except Exception as e:
    print('[WARMING] Clicking more button:', e)

  desc_xpath = '//h1[@data-e2e="browse-video-desc"]'
  desc = sd.get_element_by('xpath', desc_xpath)
  info.append(desc and clean_text(desc.text) or '')

  username_xpath = '//span[@data-e2e="browse-username"]'
  username = sd.get_element_by('xpath', username_xpath)
  info.append(username and clean_text(username.text) or '')

  date_xpath = '//span[@data-e2e="browser-nickname"]/span[3]'
  date_video = sd.get_element_by('xpath', date_xpath)
  info.append(date_video and clean_text(date_video.text) or '')

  like_count_xpath = '//strong[@data-e2e="browse-like-count"]'
  like_count = sd.get_element_by('xpath', like_count_xpath)
  info.append(like_count and clean_text(like_count.text) or '')

  comment_count_xpath = '//strong[@data-e2e="browse-comment-count"]'
  comment_count = sd.get_element_by('xpath', comment_count_xpath)
  info.append(comment_count and clean_text(comment_count.text) or '')

  share_count_xpath = '//strong[@data-e2e="undefined-count"]'
  share_count = sd.get_element_by('xpath', share_count_xpath)
  info.append(share_count and clean_text(share_count.text) or '')

  comments = get_comments(sd, parse_text_number(info[-2]))
  info.append(comments)

  return '\t'.join(info)

# %% [markdown]
# ### Login and Run session

# %%
def browser_save_cookie(sd: SearcherDriver, search: str):
  sd.get(search)
  login(sd)

  if input('Enter "y" to save cookie: ').lower() == 'y':
    save_cookie(sd, TIKTOK_COOKIE)
    print('Cookie saved')
  else:
    print('Cookie not saved')

def scraper_with_cookie(sd: SearcherDriver, search: str):
  sd.get(search)

  load_cookie(sd.driver, TIKTOK_COOKIE)

  sd.driver.refresh()

  first_video_xpath = '//div[@mode="search-video-list"]/div[1]'
  sd.get_element_by('xpath', first_video_xpath).click()

  counter = len(sd.url_scraped)

  if not sd.is_url_scraped():
    sd.append_data(get_video_info(sd))
    counter += 1
    print(f'[INFO] Videos added: {counter}')
    sd.random_sleep(1, 5)

  while True:
    try:
      result = go_next_video(sd)

      if not result:
        print('[INFO] No more videos')
        break

      is_scraped = sd.is_url_scraped()

      if not is_scraped:
        sd.append_data(get_video_info(sd))
        counter += 1
        print(f'[INFO] Videos added: {counter}')
      
      sd.random_sleep(1, 3 if is_scraped else 4)
    except Exception as e:
      print('[ERROR] Error in loop:', e)
      break

# %% [markdown]
# # Steps to scrap
# If this is the first time you are running this notebook you will need to install selenium:
# - `!pip install selenium`
# Also need to download the chromedriver from [here](https://googlechromelabs.github.io/chrome-for-testing/) and put it in the same folder as this notebook and set the path to the chromedriver.
#
# If you are using linux or mac you can use `homebrew` to install chromedriver and dont need to set explicitly the path to the chromedriver:
# - `brew install chromedriver`
#
# # Login and Scrap
# First we need get the cookies os a active session. The cell code below detect if the cookies are already saved in the file `tiktok_cookies.pkl` and if not it will open a browser and ask you to login in the site. After login you must enter "y" in the input prompted on terminal/vscode and the cookies will be saved in the file `tiktok_cookies.pkl`. Finally, `restart the kernel` run all the cells code again, now the cookies will be loaded from the file `tiktok_cookies.pkl`.
#
# You can customize the search changing the `KEYWORDS` variable.

# %%
searcher = SearcherDriver(check_captcha_fn=check_capcha)


if not os.path.exists(TIKTOK_COOKIE):
  print('[WARNING] Cookie file not found')
  url_search = build_url_search(URL_BASE, [])
  searcher.run(lambda sd: browser_save_cookie(sd, url_search))
else:
  for run_keys in RUNS:
    city, province = run_keys[-2], run_keys[-1]

    searcher.set_file(FILE.replace('<location>', f'{city}_{province}'), city)

    url_search = build_url_search(URL_BASE, run_keys)
    searcher.run(lambda sd: scraper_with_cookie(sd, url_search))
    print(f'[INFO] Run {run_keys} finished')

  print('[INFO] All runs finished')
# Out:
# [WARNING] No executable path provided. Searching for chromedriver in PATH
# [DRIVER] Scraped URLs: ['link', 'https://www.tiktok.com/@teleamazonas.noticias/video/7428993372175535366', 'https://www.tiktok.com/@ecuadorcomunicacionec/video/7366828063893490949', 'https://www.tiktok.com/@periodicodeunaec/video/7303179925329071365', 'https://www.tiktok.com/@queradiomasvacan1/video/7239036507682540806', 'https://www.tiktok.com/@queradiomasvacan2/video/7277623430801919238', 'https://www.tiktok.com/@periodicodeunaec/video/7220879299400830214', 'https://www.tiktok.com/@ecuadorcomunicacionec/video/7450677984467438853', 'https://www.tiktok.com/@dannytrellesc/video/7241324303256505605', 'https://www.tiktok.com/@andresvillalval/video/7445338536473103621', 'https://www.tiktok.com/@extraec/video/7247179929044012294', 'https://www.tiktok.com/@ecuavisaec/video/7413795223978904837', 'https://www.tiktok.com/@periodicodeunaec/video/7443832795467648311', 'https://www.tiktok.com/@periodicodeunaec/video/7338102906446417157', 'https://www.tiktok.com/@jomijomi._/video/7317714287034682630', 'https://www.tiktok.com/@ecuadorcomunicacionec/video/7364225793653820677', 'https://www.tiktok.com/@periodicodeunaec/video/7450865670264376581', 'https://www.tiktok.com/@ecuadorcomunicacionec/video/7356811391258463493', 'https://www.tiktok.com/@aquilesalcalde/video/7327347197236858118', 'https://www.tiktok.com/@periodicodeunaec/video/7312977277950659845', 'https://www.tiktok.com/@elsemanario.ec/video/7445355580992081158', 'https://www.tiktok.com/@extraec/video/7330327117021940997', 'https://www.tiktok.com/@henrybustamant/video/7381462775031450885', 'https://www.tiktok.com/@rtsecuador_/video/7365197925670079749', 'https://www.tiktok.com/@digitalinformativa/video/7285853566349151493', 'https://www.tiktok.com/@franp7615/video/7444945563130268983', 'https://www.tiktok.com/@guayaquilalrojovivo.com/video/7397151850799090950', 'https://www.tiktok.com/@ecuadorcomunicacionec/video/7229057538958855430', 'https://www.tiktok.com/@teleamazonas.noticias/video/7426034203801750789', 'https://www.tiktok.com/@periodicodeunaec/video/7308069502904831238', 'https://www.tiktok.com/@extraec/video/7312135082863594758', 'https://www.tiktok.com/@periodicodeunaec/video/7417893697200639237', 'https://www.tiktok.com/@vanerobles30/video/7192579897959730437', 'https://www.tiktok.com/@ecuadorcomunicacionec/video/7399811560283081989', 'https://www.tiktok.com/@periodicodeunaec/video/7420961584215837957', 'https://www.tiktok.com/@ecuadorcomunicacionec/video/7447329858125958405', 'https://www.tiktok.com/@periodicodeunaec/video/7302878771558862085', 'https://www.tiktok.com/@sucrenoticias/video/7264669151304731910', 'https://www.tiktok.com/@liamcito_6.21/video/7419032705813302533', 'https://www.tiktok.com/@periodicodeunaec/video/7208921302105640197', 'https://www.tiktok.com/@alojo.ec/video/7422342485508197637', 'https://www.tiktok.com/@eluniversocom/video/7374122022550473990', 'https://www.tiktok.com/@reporterinternacional/video/7171908583624297733', 'https://www.tiktok.com/@ecuadorcomunicacionec/video/7401164409265032454', 'https://www.tiktok.com/@ultimahoracol_/video/7159194609695034630', 'https://www.tiktok.com/@tctelevisionec/video/7271250140156005637', 'https://www.tiktok.com/@reporterinternacional/video/7191697678449904902', 'https://www.tiktok.com/@henrybustamant/video/7345110706997546245', 'https://www.tiktok.com/@incomprendible64/video/7322272087551331589', 'https://www.tiktok.com/@periodicodeunaec/video/7399457826763984133', 'https://www.tiktok.com/@guayacaenuk/video/7206394397116796166', 'https://www.tiktok.com/@codigorojolatino/video/7455681243535904006', 'https://www.tiktok.com/@y.mimita/video/7444668450250804536', 'https://www.tiktok.com/@ecuadorcomunicacionec/video/7426862012912635141', 'https://www.tiktok.com/@alertaguayaquil593/video/7250521752902569222', 'https://www.tiktok.com/@hechosec/video/7201568418431012102', 'https://www.tiktok.com/@xq.podcast/video/7423818887453510918', 'https://www.tiktok.com/@guayacaenuk/video/7208289717543046406', 'https://www.tiktok. ...
# [DRIVER] Running <lambda>
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@leadpluscc/video/7460725275144244485
# [INFO] Scrolling 0 times
# [INFO] Videos added: 663
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@cochi27/video/7460627725276040453
# [INFO] Scrolling 0 times
# [INFO] Videos added: 664
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7366828063893490949
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@24horasguayaquil/video/7460577903923694854
# [INFO] Scrolling 2 times
# [INFO] Videos added: 665
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7399140551452331269
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@rorysangster_/video/7460254252376591621
# [INFO] Scrolling 0 times
# [INFO] Videos added: 666
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7456223214746815750
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7339972944426306822
# [INFO] Scrolling 3 times
# [INFO] Videos added: 667
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@ecuavisaec/video/7413795223978904837
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7460591167114054918
# [INFO] Scrolling 1 times
# [INFO] Videos added: 668
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7401164409265032454
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@periodicodeunaec/video/7390798080519736581
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@periodicodeunaec/video/7450865670264376581
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@periodicodeunaec/video/7224219467394403590
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7356811391258463493
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7442419631874379064
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7405343958727003398
# [INFO] Scrolling 2 times
# [INFO] Videos added: 669
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@reporterinternacional/video/7286641902689062149
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7450677984467438853
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@elchiguiritove/video/7322196651643424005
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@la.voz.de.paquito/video/7390461529184800006
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@periodicodeunaec/video/7338102906446417157
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@periodicodeunaec/video/7208921302105640197
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@la.voz.de.paquito/video/7403002846544858374
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7445317436259175686
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@reporterinternacional/video/7191697678449904902
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7447329858125958405
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@periodicodeunaec/video/7335150275331738885
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@periodicodeunaec/video/7302878771558862085
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@periodicodeunaec/video/7443832795467648311
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@periodicodeunaec/video/7319574667306503430
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7408250397472656646
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7419167700347407621
# [INFO] Scrolling 10 times
# [INFO] Videos added: 670
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7399811560283081989
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@periodicodeunaec/video/7187952491907009798
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@lamagia_tv/video/7415084319393303814
# [INFO] Scrolling 12 times
# [INFO] Videos added: 671
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@policiaecuadoroficial/video/7216817569762790662
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@noticiaslaunika/video/7213821453597281542
# [INFO] Scrolling 0 times
# [WARMING] Elements not found: //div[contains(@class, "DivCommentContentContainer")]/div[1]/p[contains(@class, "PCommentText")]
# [INFO] Videos added: 672
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@tiemporeal_ec/video/7297615968619056390
# [INFO] Scrolling 1 times
# [INFO] Videos added: 673
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@la.voz.de.paquito/video/7436403546343492920
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@la.voz.de.paquito/video/7420864855793503493
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7334386133947698438
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@williams.veliz90/video/7460531858044996884
# [INFO] Scrolling 0 times
# [INFO] Videos added: 674
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@periodicodeunaec/video/7308828759233285381
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [WARNING] Capcha detected
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@periodicodeunaec/video/7319594563088256261
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@la.voz.de.paquito/video/7420804582311251205
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@queradiomasvacan1/video/7239036507682540806
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@extraec/video/7301428919847226630
# [INFO] Scrolling 5 times
# [INFO] Videos added: 675
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7426862012912635141
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@lamagia_tv/video/7241437730348092677
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@topictrending/video/7263327018769485061
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@incomprendible64/video/7322272087551331589
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@tctelevisionec/video/7271250140156005637
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@periodicodeunaec/video/7218793926474419461
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@fernandavelez42/video/7322249156104441130
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@chuquimarcajohn2000/video/7323341331248467205
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@instructorpauldiaz/video/7305943989826424069
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@luis.lk17/video/7460257861734550789
# [INFO] Scrolling 0 times
# [INFO] Videos added: 676
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@liam.3.01/video/7203803372829412613
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@prensaecuatoriana/video/7359592414748626182
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@noticiasalinstaste/video/7329714145400458502
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@sandyavila22/video/7270496821770882309
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@diegohurtadoec/video/7205305298548968710
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@william.1985..0/video/7415782335301324037
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@user3178860805810/video/7362638658442169606
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@kevin_cheme/video/7322462815112023302
# [INFO] Scrolling 0 times
# [WARMING] Elements not found: //div[contains(@class, "DivCommentContentContainer")]/div[1]/p[contains(@class, "PCommentText")]
# [INFO] Videos added: 677
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7372359551670177029
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@papeles97/video/6970459286287731973
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@hugoveloz2003/video/7316748358322752773
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@pelao_steven/video/7161191678211017989
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@peladoangel5/video/7235514649179966725
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@under3697/video/7161929505911606534
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@caregalla/video/7405628249750998278
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@pametorres26/video/7231157014053866779
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@eldisponible.ec/video/7415731948288494854
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@fjfjdjfjdjx/video/7452398359236726021
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@periodicodeunaec/video/7460655681994067206
# [INFO] Scrolling 12 times
# [INFO] Videos added: 678
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@tctelevisionec/video/7060541525666598149
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: True - URL: https://www.tiktok.com/@rtsecuador_/video/7238972605145844998
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [INFO] No more videos
# [INFO] Run ['delincuencia', 'grupos armados', 'robo', 'extorsion', 'secuestro', 'guayas', 'ecuador'] finished
# [DRIVER] File not found: ./data/tiktok_violencia_manabí_ecuador.csv - Creating new file
# [DRIVER] Running <lambda>
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@tiktonoticiascr/video/7443804869208657208
# [INFO] Scrolling 4 times
# [INFO] Videos added: 1
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7456223214746815750
# [INFO] Scrolling 4 times
# [INFO] Videos added: 2
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7442419631874379064
# [INFO] Scrolling 4 times
# [INFO] Videos added: 3
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@alertaguayaquil593/video/7217291677764013318
# [INFO] Scrolling 12 times
# [INFO] Videos added: 4
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuanoticiasec593/video/7460606997633813766
# [INFO] Scrolling 0 times
# [WARMING] Elements not found: //div[contains(@class, "DivCommentContentContainer")]/div[1]/p[contains(@class, "PCommentText")]
# [INFO] Videos added: 5
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@andresvillalval/video/7460604757644741893
# [INFO] Scrolling 0 times
# [INFO] Videos added: 6
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7460591167114054918
# [WARMING] Element not found: //h1[@data-e2e="browse-video-desc"]
# [WARMING] Element not found: //span[@data-e2e="browse-username"]
# [WARMING] Element not found: //span[@data-e2e="browser-nickname"]/span[3]
# [WARMING] Element not found: //strong[@data-e2e="browse-like-count"]
# [WARMING] Element not found: //strong[@data-e2e="browse-comment-count"]
# [WARMING] Element not found: //strong[@data-e2e="undefined-count"]
# [WARMING] Element not found: //div[contains(@class, "DivCommentListContainer")]
# [WARNING] Comments container not found
# [INFO] Videos added: 7
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [WARMING] Element not found: //button[@aria-label="Go to next video"]
# [INFO] No more videos
# [INFO] Run ['delincuencia', 'grupos armados', 'robo', 'extorsion', 'secuestro', 'tiroteo', 'manabí', 'ecuador'] finished
# [DRIVER] File not found: ./data/tiktok_violencia_los ríos_ecuador.csv - Creating new file
# [DRIVER] Running <lambda>
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@cochi27/video/7460627725276040453
# [WARNING] Capcha detected
# [INFO] Scrolling 0 times
# [INFO] Videos added: 1
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7460591167114054918
# [INFO] Scrolling 1 times
# [INFO] Videos added: 2
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@policiaecuadoroficial/video/7316992204470373637
# [INFO] Scrolling 1 times
# [INFO] Videos added: 3
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@diarioexxtra_/video/7278857247378230533
# [INFO] Scrolling 0 times
# [INFO] Videos added: 4
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@espacioecuadornoticias/video/7223577976540089605
# [INFO] Scrolling 4 times
# [INFO] Videos added: 5
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7456223214746815750
# [INFO] Scrolling 4 times
# [INFO] Videos added: 6
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7442419631874379064
# [INFO] Scrolling 4 times
# [INFO] Videos added: 7
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@rorysangster_/video/7460254252376591621
# [INFO] Scrolling 0 times
# [INFO] Videos added: 8
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuanoticiasec593/video/7460606997633813766
# [INFO] Scrolling 0 times
# [WARMING] Elements not found: //div[contains(@class, "DivCommentContentContainer")]/div[1]/p[contains(@class, "PCommentText")]
# [INFO] Videos added: 9
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7399140551452331269
# [INFO] Scrolling 2 times
# [INFO] Videos added: 10
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7419167700347407621
# [INFO] Scrolling 10 times
# [INFO] Videos added: 11
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7445317436259175686
# [INFO] Scrolling 4 times
# [INFO] Videos added: 12
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@elsemanario.ec/video/7415033160653819141
# [INFO] Scrolling 12 times
# [INFO] Videos added: 13
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@periodicodeunaec/video/7390798080519736581
# [INFO] Scrolling 10 times
# [INFO] Videos added: 14
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@franp7615/video/7460736195794881797
# [WARMING] Element not found: //span[@data-e2e="browser-nickname"]/span[3]
# [WARMING] Element not found: //strong[@data-e2e="browse-like-count"]
# [WARMING] Element not found: //strong[@data-e2e="browse-comment-count"]
# [WARMING] Element not found: //strong[@data-e2e="undefined-count"]
# [WARMING] Element not found: //div[contains(@class, "DivCommentListContainer")]
# [WARNING] Comments container not found
# [INFO] Videos added: 15
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [WARMING] Element not found: //button[@aria-label="Go to next video"]
# [INFO] No more videos
# [INFO] Run ['delincuencia', 'grupos armados', 'robo', 'extorsion', 'secuestro', 'los ríos', 'ecuador'] finished
# [DRIVER] File not found: ./data/tiktok_violencia_esmeraldas_ecuador.csv - Creating new file
# [DRIVER] Running <lambda>
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@gregoryrosero0/video/7445390800336276742
# [WARNING] Capcha detected
# [INFO] Scrolling 0 times
# [WARMING] Elements not found: //div[contains(@class, "DivCommentContentContainer")]/div[1]/p[contains(@class, "PCommentText")]
# [INFO] Videos added: 1
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@abg.guayaquil/video/7223438435841953029
# [INFO] Scrolling 5 times
# [INFO] Videos added: 2
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@citynoticiasec/video/7328488651787209989
# [INFO] Scrolling 0 times
# [INFO] Videos added: 3
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@notiecua/video/7200574048236014854
# [INFO] Scrolling 0 times
# [WARMING] Elements not found: //div[contains(@class, "DivCommentContentContainer")]/div[1]/p[contains(@class, "PCommentText")]
# [INFO] Videos added: 4
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@informativodigital.ec/video/7220976761847254277
# [INFO] Scrolling 0 times
# [INFO] Videos added: 5
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@carlosponcerc5/video/7377531324002782470
# [INFO] Scrolling 0 times
# [WARMING] Elements not found: //div[contains(@class, "DivCommentContentContainer")]/div[1]/p[contains(@class, "PCommentText")]
# [INFO] Videos added: 6
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@tuku_laso/video/7444922186009251127
# [INFO] Scrolling 0 times
# [INFO] Videos added: 7
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@lospatriotas.ecuador/video/7239327241748958470
# [INFO] Scrolling 0 times
# [INFO] Videos added: 8
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@radiopichincha/video/7452851268311076101
# [INFO] Scrolling 5 times
# [INFO] Videos added: 9
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@emergenciasanlorenzoec/video/7277681952126242054
# [INFO] Scrolling 0 times
# [WARMING] Elements not found: //div[contains(@class, "DivCommentContentContainer")]/div[1]/p[contains(@class, "PCommentText")]
# [INFO] Videos added: 10
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorplay/video/7291011174525619462
# [INFO] Scrolling 0 times
# [INFO] Videos added: 11
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@rdnotimas/video/7322468277219839238
# [INFO] Scrolling 4 times
# [INFO] Videos added: 12
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@reporterinternacional/video/7150237695464312070
# [INFO] Scrolling 10 times
# [INFO] Videos added: 13
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@che5615/video/7460306389710212358
# [INFO] Scrolling 0 times
# [INFO] Videos added: 14
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@alertaguayaquil593/video/7217291677764013318
# [INFO] Scrolling 12 times
# [INFO] Videos added: 15
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7424327643379617029
# [INFO] Scrolling 2 times
# [INFO] Videos added: 16
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@byron2490/video/7289540421066231045
# [INFO] Scrolling 12 times
# [INFO] Videos added: 17
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7356811391258463493
# [WARNING] Capcha detected
# [INFO] Scrolling 12 times
# [INFO] Videos added: 18
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@angelsolorzano277/video/7239580217549802757
# [INFO] Scrolling 12 times
# [INFO] Videos added: 19
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@queradiomasvacan1/video/7239036507682540806
# [INFO] Scrolling 11 times
# [INFO] Videos added: 20
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@zaracay_television/video/7329680692370001157
# [INFO] Scrolling 0 times
# [WARMING] Elements not found: //div[contains(@class, "DivCommentContentContainer")]/div[1]/p[contains(@class, "PCommentText")]
# [INFO] Videos added: 21
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@la.voz.de.paquito/video/7420804582311251205
# [INFO] Scrolling 1 times
# [INFO] Videos added: 22
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@teveoec/video/7135117752335060230
# [INFO] Scrolling 0 times
# [WARMING] Elements not found: //div[contains(@class, "DivCommentContentContainer")]/div[1]/p[contains(@class, "PCommentText")]
# [INFO] Videos added: 23
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7399140551452331269
# [INFO] Scrolling 2 times
# [INFO] Videos added: 24
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@saetatvesmeraldas/video/7453492888203283718
# [INFO] Scrolling 0 times
# [WARMING] Elements not found: //div[contains(@class, "DivCommentContentContainer")]/div[1]/p[contains(@class, "PCommentText")]
# [INFO] Videos added: 25
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7451804618729868550
# [INFO] Scrolling 0 times
# [INFO] Videos added: 26
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@tctelevisionec/video/7060541525666598149
# [INFO] Scrolling 3 times
# [INFO] Videos added: 27
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7426862012912635141
# [INFO] Scrolling 2 times
# [INFO] Videos added: 28
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@toaquiza.luis5/video/7460520848508718342
# [INFO] Scrolling 0 times
# [INFO] Videos added: 29
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@willinsonlozano/video/7245867002429033733
# [INFO] Scrolling 12 times
# [INFO] Videos added: 30
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7459619236919463173
# [INFO] Scrolling 4 times
# [INFO] Videos added: 31
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@quito_querido/video/7382751417523506437
# [INFO] Scrolling 4 times
# [INFO] Videos added: 32
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@tiemporeal_ec/video/7304526591072210182
# [INFO] Scrolling 1 times
# [INFO] Videos added: 33
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@tctelevisionec/video/7271250140156005637
# [INFO] Scrolling 12 times
# [INFO] Videos added: 34
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@rostrosec/video/7211367274186280197
# [INFO] Scrolling 0 times
# [INFO] Videos added: 35
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [INFO] No more videos
# [INFO] Run ['delincuencia', 'grupos armados', 'robo', 'extorsion', 'secuestro', 'esmeraldas', 'ecuador'] finished
# [DRIVER] File not found: ./data/tiktok_violencia_machala_ecuador.csv - Creating new file
# [DRIVER] Running <lambda>
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7456223214746815750
# [INFO] Scrolling 4 times
# [INFO] Videos added: 1
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@liderfmtiktok/video/7420807772373060869
# [WARMING] Element not found: //button[contains(@class, "ButtonExpand") and contains(text(), "more")]
# [WARMING] Element not found: //h1[@data-e2e="browse-video-desc"]
# [WARMING] Element not found: //span[@data-e2e="browse-username"]
# [WARMING] Element not found: //span[@data-e2e="browser-nickname"]/span[3]
# [WARMING] Element not found: //strong[@data-e2e="browse-like-count"]
# [WARMING] Element not found: //strong[@data-e2e="browse-comment-count"]
# [WARMING] Element not found: //strong[@data-e2e="undefined-count"]
# [WARMING] Element not found: //div[contains(@class, "DivCommentListContainer")]
# [WARNING] Comments container not found
# [INFO] Videos added: 2
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [WARMING] Element not found: //button[@aria-label="Go to next video"]
# [INFO] No more videos
# [INFO] Run ['delincuencia', 'grupos armados', 'robo', 'extorsion', 'secuestro', 'machala', 'ecuador'] finished
# [DRIVER] File not found: ./data/tiktok_violencia_santo domingo_ecuador.csv - Creating new file
# [DRIVER] Running <lambda>
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@choneeferk/video/7231989852479163654
# [WARNING] Capcha detected
# [INFO] Scrolling 0 times
# [INFO] Videos added: 1
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@zaracay_television/video/7442455532373413176
# [INFO] Scrolling 1 times
# [INFO] Videos added: 2
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7445317436259175686
# [INFO] Scrolling 4 times
# [INFO] Videos added: 3
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@radiovigiafmoficial/video/7460860500826443014
# [INFO] Scrolling 1 times
# [INFO] Videos added: 4
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@liamcito_6.21/video/7203783549747580165
# [INFO] Scrolling 9 times
# [INFO] Videos added: 5
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@radioflama104.5/video/7349176867129216261
# [INFO] Scrolling 0 times
# [INFO] Videos added: 6
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7419167700347407621
# [INFO] Scrolling 10 times
# [INFO] Videos added: 7
# [DRIVER] Sleeping for 4 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@majestadtvec/video/7366625244229963013
# [INFO] Scrolling 0 times
# [INFO] Videos added: 8
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7401164409265032454
# [INFO] Scrolling 7 times
# [INFO] Videos added: 9
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7447329858125958405
# [INFO] Scrolling 0 times
# [INFO] Videos added: 10
# [DRIVER] Sleeping for 3 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@periodicodeunaec/video/7450865670264376581
# [INFO] Scrolling 12 times
# [INFO] Videos added: 11
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@ecuadorcomunicacionec/video/7424327643379617029
# [INFO] Scrolling 2 times
# [INFO] Videos added: 12
# [DRIVER] Sleeping for 2 seconds
# [INFO] Going to next video
# [DRIVER] Scraped: False - URL: https://www.tiktok.com/@alertaguayaquil593/video/7217291677764013318
# [WARMING] Element not found: //strong[@data-e2e="browse-like-count"]
# [WARMING] Element not found: //strong[@data-e2e="browse-comment-count"]
# [WARMING] Element not found: //strong[@data-e2e="undefined-count"]
# [WARMING] Element not found: //div[contains(@class, "DivCommentListContainer")]
# [WARNING] Comments container not found
# [INFO] Videos added: 13
# [DRIVER] Sleeping for 1 seconds
# [INFO] Going to next video
# [WARMING] Element not found: //button[@aria-label="Go to next video"]
# [INFO] No more videos
# [INFO] Run ['delincuencia', 'grupos armados', 'robo', 'extorsion', 'secuestro', 'santo domingo', 'ecuador'] finished
# [INFO] All runs finished
